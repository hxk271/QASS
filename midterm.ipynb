# %% [markdown]
# <a href="https://colab.research.google.com/github/hxk271/QASS/blob/main/midterm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 중간시험
#
# > 사회학에서도 **공간자료(spatial data)**에 대한 관심이 부쩍 높아지고 있다. John Snow의 19세기 런던 콜레라 연구 이래 다양한 공간자료가 **지리정보시스템(geographical information system; GIS)** 안에 통합되었을 때 뛰어난 사회과학적 통찰을 제공한다는 사실은 이미 오래 전부터 잘 알려져 있다. 보다 최근에는 사진을 찍거나 트윗을 올렸을 때 위치정보가 **지오태그(geotag)**되므로 일상생활에 대한 공간자료가 더 세밀하게 축적되어가고 있다.
# > <br><br>
# > 오늘 중간시험에서 사용할 자료는 건강보험관리공단에서 제공하는 76,034개의 병$\cdot$의원 정보이다. 이 자료는 구글 드라이브에서 아래 링크를 통해 다운로드 받을 수 있다: <br>
# > https://drive.google.com/uc?id=1YIaxbVIisG1Q7AtgUIeJzjbj8SpMfX_p
# > <br><br>
# > 다음 질문에 모두 답하기 위한 파이썬 코드를 작성하고 **SocStatsPrac@gmail.com**로 ipynb 파일을 제출하시오(구글콜랩에서 [File]-[Download]를 선택할 것). 답안 코드 안에 반드시 이름과 학번을 포함하시오.

# %% [markdown]
# ## 1번 문제(50점)
#
# > 좌표정보 $x$와 $y$는 각각 경도와 위도이다. 이를 토대로 우리나라 병의원 입지의 산점도(scatterplot)를 그리시오(기본점수 40점). 이때 해당 의료기관에 종사하는 총의사에 비례하여 각 점(dot)의 크기가 크거나 작게 나오도록 그리시오(가산점 10점).

# %% [markdown]
# ## 2번 문제(50점)
#
# > 충청북도에 한정하여 의료기관 유형별로 총의사수가 각각 몇 명인지 출력하시오.
# ---
# (답안 예시)
# 상급종합: xxx명, 종합병원: xxx명, 병원: xxx명, ...
